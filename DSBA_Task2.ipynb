# %% [markdown]
# # **Prediction Using Decision Tree Algorithm**
#
# Create the Decision Tree classifier and visualize it graphically.
#
# The purpose is if we feed any new data to this classifier, it would be able to predict the right class accordingly.

# %% [markdown]
# **Preparing the iris DataFrame**

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
print(df.head(5))
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target'] = iris.target

# %%
df.head(10)
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
# 3                4.6               3.1  ...               0.2       0
# 4                5.0               3.6  ...               0.2       0
# 5                5.4               3.9  ...               0.4       0
# 6                4.6               3.4  ...               0.3       0
# 7                5.0               3.4  ...               0.2       0
# 8                4.4               2.9  ...               0.2       0
# 9                4.9               3.1  ...               0.1       0
#
# [10 rows x 5 columns]

# %% [markdown]
# **Shape of our Dataset**
#
# *This shows how many rows & columns are there in dataset*

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# **Null Values in our Dataset**

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %% [markdown]
# **Info of our Dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %% [markdown]
# **Describing our Dataset**
#
# This shows min , max , percentile , mean , standard deviation of our dataset

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  ...  petal width (cm)      target
# count         150.000000        150.000000  ...        150.000000  150.000000
# mean            5.843333          3.057333  ...          1.199333    1.000000
# std             0.828066          0.435866  ...          0.762238    0.819232
# min             4.300000          2.000000  ...          0.100000    0.000000
# 25%             5.100000          2.800000  ...          0.300000    0.000000
# 50%             5.800000          3.000000  ...          1.300000    1.000000
# 75%             6.400000          3.300000  ...          1.800000    2.000000
# max             7.900000          4.400000  ...          2.500000    2.000000
#
# [8 rows x 5 columns]

# %% [markdown]
# **Distribution of Iris Flower target in Dataset**

# %%
df.target.value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# Name: target, dtype: int64

# %% [markdown]
# We have,
# * setosa - 50
# * versicolor - 50
# * virginica - 50

# %% [markdown]
# **Visualizing the dataset using Matplotlib & Seaborn**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Let's find correlation of our dataset**
#
# Correlation is of 2 types:
# 1. Positive Correlation
# 2. Negative Correlation

# %%
correlation = df.corr()

# %% [markdown]
# **Correlation using Heatmap**

# %%
plt.figure(figsize=(10,7))
sns.heatmap(correlation, annot=True, cmap='Blues')
plt.show()

# %% [markdown]
# **Relation Between target & Attributes using Barplot**
#
# 1] Sepal Length vs target

# %%
plt.figure(figsize=(16,9))
sns.barplot(x=df.target,y=df['sepal length (cm)'],data=df)
plt.show()

# %% [markdown]
# 2] Sepal Width vs target

# %%
plt.figure(figsize=(16,9))
sns.barplot(x=df.target,y=df['sepal width (cm)'],data=df)
plt.show()

# %% [markdown]
# 3] Petal Length vs target

# %%
plt.figure(figsize=(16,9))
sns.barplot(x=df.target,y=df['petal length (cm)'],data=df)
plt.show()

# %% [markdown]
# 4] Petal Width vs target

# %%
plt.figure(figsize=(16,9))
sns.barplot(x=df.target,y=df['petal width (cm)'],data=df)
plt.show()

# %% [markdown]
# **Now we will plot a Pairplot**
#
# It shows pairwise relationship of the dataset

# %%
sns.pairplot(df, hue='target', palette='Paired')
plt.show()

# %% [markdown]
# **Creating Decision Tree Classifier**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
X = df.drop(['target'], axis=1)
y = df['target']

# %%
tree=DecisionTreeClassifier()
tree.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# **Visualizing Decision Tree**

# %%
# !pip install pydotplus
# !apt-get install graphviz -y
# Out:
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# graphviz is already the newest version (2.40.1-2).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
from six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# %%
dot_data = StringIO()
export_graphviz(tree, out_file=dot_data, feature_names=iris.feature_names,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# # **THANK YOU**
